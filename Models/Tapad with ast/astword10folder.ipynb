# %%
import os, glob, random
import pandas as pd
import numpy as np
import torch
import torchaudio
import torch.nn.functional as F
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

from torch.utils.data import Dataset, DataLoader
from torchaudio.transforms import MelSpectrogram, AmplitudeToDB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn.utils.multiclass import unique_labels

# %%
label_to_id = {'TVMA': 0, 'TVFOURTEEN': 1, 'TVYSEVEN': 2, 'Non-Profane': 3}
id_to_label = {v: k for k, v in label_to_id.items()}

# %%
csv_path = "/Users/raj/University/AVS 8/AVS8_AAU_Audio_Main/Tapad/newclass.csv"
df = pd.read_csv(csv_path).dropna()
df["Word"] = df["Word"].str.strip()
df["Class"] = df["Class"].str.strip()

label_map = dict(zip(df["Word"] + ".mp3", df["Class"]))

# %%
mel_transform = MelSpectrogram(sample_rate=16000, n_fft=1024, hop_length=320, n_mels=128)
db_transform = AmplitudeToDB(top_db=80)

# %%
class WordAudioDataset(Dataset):
    def __init__(self, audio_dir, label_map, transform=None):
        self.audio_dir = audio_dir
        self.label_map = label_map
        self.transform = transform
        self.label_to_id = {'TVMA': 0, 'TVFOURTEEN': 1, 'TVYSEVEN': 2, 'Non-Profane': 3}

        all_files = glob.glob(os.path.join(audio_dir, "**/*.mp3"), recursive=True)
        self.files = [f for f in all_files if os.path.basename(f) in label_map]

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        attempts = 0
        while attempts < 10:
            try:
                path = self.files[idx]
                filename = os.path.basename(path)
                label_name = self.label_map[filename]
                label = self.label_to_id[label_name]

                if not os.path.exists(path):
                    raise FileNotFoundError(f"Missing: {path}")

                waveform, sr = torchaudio.load(path)
                if waveform.shape[1] < 16000:
                    waveform = F.pad(waveform, (0, 16000 - waveform.shape[1]))
                else:
                    waveform = waveform[:, :16000]

                mel = self.transform(waveform)
                mel = db_transform(mel)
                mel = torch.nn.functional.interpolate(mel.unsqueeze(0), size=(224, 224), mode="bilinear").squeeze(0)
                return mel, label

            except Exception as e:
                print(f"Skipping sample {idx} ({filename}): {e}")
                idx = (idx + 1) % len(self.files)
                attempts += 1

        raise RuntimeError("Too many consecutive loading failures.")

# %%
audio_dir = "/Users/raj/University/AVS 8/AVS8_AAU_Audio_Main/Tapad/newaudio"
dataset = WordAudioDataset(audio_dir, label_map, transform=mel_transform)

train_loader = DataLoader(dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(dataset, batch_size=16, shuffle=False)

# %%
label_counter = Counter()

for i in range(len(dataset)):
    try:
        _, label = dataset[i]
        label_counter[label] += 1
    except:
        continue

print(f" Total samples in dataset: {len(dataset)}\n")
print(" Samples per class:")
for label_id, count in sorted(label_counter.items()):
    label_name = id_to_label[label_id]
    print(f"  {label_name:12} → {count} samples")
# Out:
# 📦 Total samples in dataset: 1694
#
# 📊 Samples per class:
#   TVMA         → 1037 samples
#   TVFOURTEEN   → 517 samples
#   TVYSEVEN     → 140 samples

# %%
import timm
import torch.nn as nn

model = timm.create_model("vit_base_patch16_224", pretrained=True)
model.patch_embed.proj = nn.Conv2d(1, 768, kernel_size=(16, 16), stride=(16, 16))
model.head = nn.Linear(model.head.in_features, len(label_to_id))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# objc[58078]: Class AVFFrameReceiver is implemented in both /opt/anaconda3/envs/mp1/lib/libavdevice.58.8.100.dylib (0x1173a4798) and /opt/anaconda3/envs/mp1/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x17ed803a8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[58078]: Class AVFAudioReceiver is implemented in both /opt/anaconda3/envs/mp1/lib/libavdevice.58.8.100.dylib (0x1173a47e8) and /opt/anaconda3/envs/mp1/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x17ed803f8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# VisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(1, 768, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (norm_pre): Identity()
#   (blocks): Sequential(
#     (0): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (8): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (9): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (10): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (11): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (fc_norm): Identity()
#   (head): Linear(in_features=768, out_features=4, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# %%
best_acc = 0

for epoch in range(20):
    model.train()
    total_loss = 0

    for mel, label in train_loader:
        mel, label = mel.to(device), label.to(device)

        optimizer.zero_grad()
        output = model(mel)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    # Evaluation
    model.eval()
    all_preds, all_labels, all_probs = [], [], []

    with torch.no_grad():
        for mel, label in val_loader:
            mel, label = mel.to(device), label.to(device)
            output = model(mel)

            probs = torch.softmax(output, dim=1).cpu().numpy()
            preds = torch.argmax(output, dim=1).cpu().numpy()

            all_probs.extend(probs)
            all_preds.extend(preds)
            all_labels.extend(label.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds) * 100
    try:
        auc = roc_auc_score(label_binarize(all_labels, classes=list(id_to_label.keys())), all_probs, multi_class='ovr') * 100
        auc_str = f"{auc:.2f}"
    except:
        auc_str = "N/A"

    print(f" Epoch {epoch+1:02d} | Loss: {total_loss/len(train_loader):.4f} | Acc: {acc:.2f}% | AUC: {auc_str}")

    present_labels = unique_labels(all_labels, all_preds)
    target_names = [id_to_label[i] for i in present_labels]
    print(classification_report(all_labels, all_preds, target_names=target_names, zero_division=0))

    if acc > best_acc:
        best_acc = acc
        torch.save(model.state_dict(), "ast_10_folder.pth")
        print(f" Saved best model with accuracy: {round(best_acc, 2)}")

    scheduler.step()
# Out:
# 📊 Epoch 01 | Loss: 1.1192 | Acc: 61.22% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.61      1.00      0.76      1037
#   TVFOURTEEN       0.00      0.00      0.00       517
#     TVYSEVEN       0.00      0.00      0.00       140
#
#     accuracy                           0.61      1694
#    macro avg       0.20      0.33      0.25      1694
# weighted avg       0.37      0.61      0.46      1694
#
# ✅ Saved best model with accuracy: 61.22
# 📊 Epoch 02 | Loss: 0.8865 | Acc: 65.35% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.64      1.00      0.78      1037
#   TVFOURTEEN       0.93      0.14      0.25       517
#     TVYSEVEN       0.00      0.00      0.00       140
#
#     accuracy                           0.65      1694
#    macro avg       0.52      0.38      0.34      1694
# weighted avg       0.67      0.65      0.55      1694
#
# ✅ Saved best model with accuracy: 65.35
# 📊 Epoch 03 | Loss: 0.8150 | Acc: 71.49% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.70      0.96      0.81      1037
#   TVFOURTEEN       0.80      0.42      0.55       517
#     TVYSEVEN       0.00      0.00      0.00       140
#
#     accuracy                           0.71      1694
#    macro avg       0.50      0.46      0.45      1694
# weighted avg       0.67      0.71      0.66      1694
#
# ✅ Saved best model with accuracy: 71.49
# 📊 Epoch 04 | Loss: 0.7439 | Acc: 74.56% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.74      0.94      0.83      1037
#   TVFOURTEEN       0.77      0.56      0.65       517
#     TVYSEVEN       0.75      0.02      0.04       140
#
#     accuracy                           0.75      1694
#    macro avg       0.75      0.51      0.51      1694
# weighted avg       0.75      0.75      0.71      1694
#
# ✅ Saved best model with accuracy: 74.56
# 📊 Epoch 05 | Loss: 0.7434 | Acc: 73.14% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.82      0.78      0.80      1037
#   TVFOURTEEN       0.61      0.76      0.68       517
#     TVYSEVEN       0.55      0.26      0.35       140
#
#     accuracy                           0.73      1694
#    macro avg       0.66      0.60      0.61      1694
# weighted avg       0.74      0.73      0.73      1694
#
# 📊 Epoch 06 | Loss: 0.6806 | Acc: 76.51% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.80      0.88      0.84      1037
#   TVFOURTEEN       0.70      0.75      0.72       517
#     TVYSEVEN       0.00      0.00      0.00       140
#
#     accuracy                           0.77      1694
#    macro avg       0.50      0.54      0.52      1694
# weighted avg       0.70      0.77      0.73      1694
#
# ✅ Saved best model with accuracy: 76.51
# 📊 Epoch 07 | Loss: 0.6385 | Acc: 83.41% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.82      0.96      0.88      1037
#   TVFOURTEEN       0.87      0.74      0.80       517
#     TVYSEVEN       0.90      0.25      0.39       140
#
#     accuracy                           0.83      1694
#    macro avg       0.86      0.65      0.69      1694
# weighted avg       0.84      0.83      0.82      1694
#
# ✅ Saved best model with accuracy: 83.41
# 📊 Epoch 08 | Loss: 0.5535 | Acc: 83.29% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.88      0.91      0.90      1037
#   TVFOURTEEN       0.93      0.65      0.76       517
#     TVYSEVEN       0.49      0.91      0.64       140
#
#     accuracy                           0.83      1694
#    macro avg       0.77      0.83      0.77      1694
# weighted avg       0.87      0.83      0.84      1694
#
# 📊 Epoch 09 | Loss: 0.4996 | Acc: 83.94% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.90      0.90      0.90      1037
#   TVFOURTEEN       0.74      0.91      0.81       517
#     TVYSEVEN       1.00      0.11      0.21       140
#
#     accuracy                           0.84      1694
#    macro avg       0.88      0.64      0.64      1694
# weighted avg       0.86      0.84      0.82      1694
#
# ✅ Saved best model with accuracy: 83.94
# 📊 Epoch 10 | Loss: 0.4222 | Acc: 90.73% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.94      0.93      0.94      1037
#   TVFOURTEEN       0.85      0.92      0.88       517
#     TVYSEVEN       0.90      0.67      0.77       140
#
#     accuracy                           0.91      1694
#    macro avg       0.90      0.84      0.86      1694
# weighted avg       0.91      0.91      0.91      1694
#
# ✅ Saved best model with accuracy: 90.73
# 📊 Epoch 11 | Loss: 0.2142 | Acc: 96.99% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.97      0.99      0.98      1037
#   TVFOURTEEN       0.96      0.97      0.97       517
#     TVYSEVEN       1.00      0.84      0.91       140
#
#     accuracy                           0.97      1694
#    macro avg       0.98      0.93      0.95      1694
# weighted avg       0.97      0.97      0.97      1694
#
# ✅ Saved best model with accuracy: 96.99
# 📊 Epoch 12 | Loss: 0.0910 | Acc: 97.87% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.98      0.99      0.98      1037
#   TVFOURTEEN       0.97      0.98      0.97       517
#     TVYSEVEN       1.00      0.90      0.95       140
#
#     accuracy                           0.98      1694
#    macro avg       0.98      0.96      0.97      1694
# weighted avg       0.98      0.98      0.98      1694
#
# ✅ Saved best model with accuracy: 97.87
# 📊 Epoch 13 | Loss: 0.0915 | Acc: 97.87% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.98      0.99      0.98      1037
#   TVFOURTEEN       0.97      0.97      0.97       517
#     TVYSEVEN       1.00      0.94      0.97       140
#
#     accuracy                           0.98      1694
#    macro avg       0.98      0.97      0.98      1694
# weighted avg       0.98      0.98      0.98      1694
#
# 📊 Epoch 14 | Loss: 0.0837 | Acc: 89.26% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.99      0.83      0.90      1037
#   TVFOURTEEN       0.80      0.99      0.88       517
#     TVYSEVEN       0.76      0.99      0.86       140
#
#     accuracy                           0.89      1694
#    macro avg       0.85      0.94      0.88      1694
# weighted avg       0.91      0.89      0.89      1694
#
# 📊 Epoch 15 | Loss: 0.0860 | Acc: 95.81% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       1.00      0.95      0.97      1037
#   TVFOURTEEN       0.88      1.00      0.94       517
#     TVYSEVEN       0.99      0.86      0.92       140
#
#     accuracy                           0.96      1694
#    macro avg       0.96      0.94      0.95      1694
# weighted avg       0.96      0.96      0.96      1694
#
# 📊 Epoch 16 | Loss: 0.1105 | Acc: 99.41% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.99      1.00      1.00      1037
#   TVFOURTEEN       0.99      0.99      0.99       517
#     TVYSEVEN       1.00      0.97      0.99       140
#
#     accuracy                           0.99      1694
#    macro avg       1.00      0.99      0.99      1694
# weighted avg       0.99      0.99      0.99      1694
#
# ✅ Saved best model with accuracy: 99.41
# 📊 Epoch 17 | Loss: 0.0569 | Acc: 98.70% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.99      1.00      0.99      1037
#   TVFOURTEEN       1.00      0.97      0.98       517
#     TVYSEVEN       0.94      0.98      0.96       140
#
#     accuracy                           0.99      1694
#    macro avg       0.98      0.98      0.98      1694
# weighted avg       0.99      0.99      0.99      1694
#
# 📊 Epoch 18 | Loss: 0.0212 | Acc: 99.53% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.99      1.00      1.00      1037
#   TVFOURTEEN       1.00      0.99      0.99       517
#     TVYSEVEN       1.00      0.99      0.99       140
#
#     accuracy                           1.00      1694
#    macro avg       1.00      0.99      0.99      1694
# weighted avg       1.00      1.00      1.00      1694
#
# ✅ Saved best model with accuracy: 99.53
# 📊 Epoch 19 | Loss: 0.0150 | Acc: 99.47% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       1.00      0.99      1.00      1037
#   TVFOURTEEN       0.98      1.00      0.99       517
#     TVYSEVEN       1.00      0.99      1.00       140
#
#     accuracy                           0.99      1694
#    macro avg       0.99      1.00      0.99      1694
# weighted avg       0.99      0.99      0.99      1694
#
# 📊 Epoch 20 | Loss: 0.0160 | Acc: 97.40% | AUC: N/A
#               precision    recall  f1-score   support
#
#         TVMA       0.96      1.00      0.98      1037
#   TVFOURTEEN       1.00      0.94      0.97       517
#     TVYSEVEN       1.00      0.90      0.95       140
#
#     accuracy                           0.97      1694
#    macro avg       0.99      0.95      0.97      1694
# weighted avg       0.98      0.97      0.97      1694

# %%
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=[id_to_label[i] for i in range(4)],
            yticklabels=[id_to_label[i] for i in range(4)])
plt.xlabel("Predicted")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
import torch
import torchaudio
from torchaudio.transforms import MelSpectrogram, AmplitudeToDB

# Update to your path
model_path =  "ast_10_folder.pth"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load trained model
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval().to(device)

# Mel transforms
sample_rate = 16000
mel_transform = MelSpectrogram(sample_rate=sample_rate, n_fft=1024, hop_length=320, n_mels=128)
db_transform = AmplitudeToDB(top_db=80)

# Labels
label_to_id = {'TVMA': 0, 'TVFOURTEEN': 1, 'TVYSEVEN': 2, 'Non-Profane': 3}
id_to_label = {v: k for k, v in label_to_id.items()}

# %%
def predict_on_audio(file_path, model, mel_transform, db_transform, device,
                     window_sec=1.0, stride_sec=0.5, threshold=0.5):
    waveform, sr = torchaudio.load(file_path)
    waveform = torchaudio.functional.resample(waveform, sr, sample_rate)
    waveform = waveform.mean(dim=0, keepdim=True)  # mono

    window_samples = int(window_sec * sample_rate)
    stride_samples = int(stride_sec * sample_rate)
    total_samples = waveform.shape[1]

    predictions, confidences, segments = [], [], []

    for start in range(0, total_samples - window_samples + 1, stride_samples):
        end = start + window_samples
        segment = waveform[:, start:end]

        with torch.no_grad():
            mel = mel_transform(segment)
            mel_db = db_transform(mel)
            mel_db = mel_db.unsqueeze(0)  # [1, 1, H, W]

            if mel_db.shape[-1] < 10:
                predictions.append(None)
                confidences.append(None)
                segments.append((start, end))
                continue

            mel_resized = torch.nn.functional.interpolate(mel_db, size=(224, 224), mode='bilinear', align_corners=False)
            output = model(mel_resized.to(device))
            probs = torch.softmax(output, dim=1).cpu().squeeze()
            conf, pred = torch.max(probs, dim=0)

                        # Calculate energy of the segment
            energy = segment.abs().mean().item()

            # Suppress suspiciously quiet or low-confidence TVMA predictions
            if conf < threshold or (pred.item() == label_to_id["TVMA"] and energy < 0.90):
                predictions.append(None)
                confidences.append(None)
            else:
                predictions.append(pred.item())
                confidences.append(conf.item())

            segments.append((start, end))


    return waveform.squeeze().numpy(), segments, predictions, confidences

# %%
import matplotlib.pyplot as plt
from IPython.display import Audio

def plot_predictions(waveform_np, segments, predictions, confidences, sr=sample_rate):
    plt.figure(figsize=(14, 4))
    plt.plot(waveform_np, alpha=0.7)
    
    for (start, end), label_id, conf in zip(segments, predictions, confidences):
        if label_id is not None:
            label = id_to_label[label_id]
            plt.axvspan(start, end, color='red', alpha=0.2)
            plt.text((start + end) // 2, 0.5, f"{label}\n({conf:.2f})",
                     color='red', fontsize=10, rotation=90, ha='center', va='bottom')
    
    plt.title("Predicted Labels per Segment (with Confidence)")
    plt.xlabel("Sample index")
    plt.ylabel("Amplitude")
    plt.tight_layout()
    plt.grid(True)
    plt.show()

# %%
#  Replace with your test file path
audio_path = "/Users/raj/University/AVS 8/AVS8_AAU_Audio_Main/newdata/new/line_1130.mp3"

# audio_path = "/Users/raj/University/AVS 8/AVS8_AAU_Audio_Main/Synthetic Audio/Syn_Aud_categorized/non_profane/3174_non_profane.mp3"

waveform_np, segments, predictions, confidences = predict_on_audio(
    audio_path, model, mel_transform, db_transform, device,
    window_sec=.5, stride_sec=0.5, threshold=.99
)


plot_predictions(waveform_np, segments, predictions, confidences)
Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
labels_to_beep = ["TVMA", "TVFOURTEEN", "TVYSEVEN"]  # You can adjust this
waveform_tensor = torch.tensor(waveform_np).unsqueeze(0)

beeped_waveform = apply_beep_on_predictions(waveform_tensor, sample_rate, segments, predictions, labels_to_beep)

# Save it if you want
output_path = "beeped_output123.wav"
torchaudio.save(output_path, beeped_waveform, sample_rate)
print(f"✅ Saved to: {output_path}")

# Play it in notebook
from IPython.display import Audio
Audio(output_path)
# Out:
# ✅ Saved to: beeped_output123.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
